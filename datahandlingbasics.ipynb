# %%
## importing required libraries
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as sns

# %%
## reading the csv file
df = pd.read_csv("/home/student/emp.csv")

# %%
df
# Out:
#     empno       ename         job        DOJ        DOB  deptid   salary
# 0       1        Anil       Clerk        NaN        NaN     NaN      NaN
# 1       2  Balkrushna         NaN  15-Jul-17  16-Mar-12    10.0  10000.0
# 2       3      Mathew     Manager  16-Mar-12  16-Mar-92    20.0  50000.0
# 3       4       Suhas     Manager  16-Mar-12  17-Mar-91    20.0      NaN
# 4       5       Vimal  Accountant  18-Mar-17  18-Mar-91    20.0  45000.0
# 5       6       Kamal  Accountant  19-Nov-13  18-Mar-91    20.0  45000.0
# 6       7       Nanda     Manager  20-Mar-12  20-Jan-97    20.0  52000.0
# 7       8      Khushi     Manager  21-Mar-12  21-Jun-94    20.0  56000.0
# 8       9       Sayee      Cleark  16-Mar-12  22-Aug-98     NaN  21000.0
# 9      10       Sakhi  Accountant  23-Mar-12  14-Mar-91    30.0  46000.0
# 10     11      Soniya  Accountant  24-Mar-14  24-Mar-91    30.0  47000.0
# 11      1        Anil       Clerk        NaN        NaN     NaN      NaN

# %%
## head() displays the first five records in the file
df.head()
# Out:
#    empno       ename         job        DOJ        DOB  deptid   salary
# 0      1        Anil       Clerk        NaN        NaN     NaN      NaN
# 1      2  Balkrushna         NaN  15-Jul-17  16-Mar-12    10.0  10000.0
# 2      3      Mathew     Manager  16-Mar-12  16-Mar-92    20.0  50000.0
# 3      4       Suhas     Manager  16-Mar-12  17-Mar-91    20.0      NaN
# 4      5       Vimal  Accountant  18-Mar-17  18-Mar-91    20.0  45000.0

# %%
## tail() displays the last 5 records of the file
df.tail()
# Out:
#     empno   ename         job        DOJ        DOB  deptid   salary
# 7       8  Khushi     Manager  21-Mar-12  21-Jun-94    20.0  56000.0
# 8       9   Sayee      Cleark  16-Mar-12  22-Aug-98     NaN  21000.0
# 9      10   Sakhi  Accountant  23-Mar-12  14-Mar-91    30.0  46000.0
# 10     11  Soniya  Accountant  24-Mar-14  24-Mar-91    30.0  47000.0
# 11      1    Anil       Clerk        NaN        NaN     NaN      NaN

# %%
## checking the data type of a field
df['salary'].dtype
# Out:
# dtype('float64')

# %%
df.dtypes
# Out:
# empno       int64
# ename      object
# job        object
# DOJ        object
# DOB        object
# deptid    float64
# salary    float64
# dtype: object

# %% [markdown]
# df.columns

# %%
df.columns
# Out:
# Index(['empno', 'ename', 'job', 'DOJ', 'DOB', 'deptid', 'salary'], dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=12, step=1),
#  Index(['empno', 'ename', 'job', 'DOJ', 'DOB', 'deptid', 'salary'], dtype='object')]

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 84

# %%
## view statistical data of the dataframe 
df.describe()
# Out:
#            empno     deptid        salary
# count  12.000000   9.000000      9.000000
# mean    5.583333  21.111111  41333.333333
# std     3.476109   6.009252  15329.709717
# min     1.000000  10.000000  10000.000000
# 25%     2.750000  20.000000  45000.000000
# 50%     5.500000  20.000000  46000.000000
# 75%     8.250000  20.000000  50000.000000
# max    11.000000  30.000000  56000.000000

# %%
df['salary'].mean()
# Out:
# 41333.333333333336

# %%
df.sample(5)
# Out:
#     empno       ename         job        DOJ        DOB  deptid   salary
# 9      10       Sakhi  Accountant  23-Mar-12  14-Mar-91    30.0  46000.0
# 1       2  Balkrushna         NaN  15-Jul-17  16-Mar-12    10.0  10000.0
# 8       9       Sayee      Cleark  16-Mar-12  22-Aug-98     NaN  21000.0
# 7       8      Khushi     Manager  21-Mar-12  21-Jun-94    20.0  56000.0
# 11      1        Anil       Clerk        NaN        NaN     NaN      NaN

# %%
df_sub=df[df['salary']>12000]

# %%
df_sub
# Out:
#     empno   ename         job        DOJ        DOB  deptid   salary
# 2       3  Mathew     Manager  16-Mar-12  16-Mar-92    20.0  50000.0
# 4       5   Vimal  Accountant  18-Mar-17  18-Mar-91    20.0  45000.0
# 5       6   Kamal  Accountant  19-Nov-13  18-Mar-91    20.0  45000.0
# 6       7   Nanda     Manager  20-Mar-12  20-Jan-97    20.0  52000.0
# 7       8  Khushi     Manager  21-Mar-12  21-Jun-94    20.0  56000.0
# 8       9   Sayee      Cleark  16-Mar-12  22-Aug-98     NaN  21000.0
# 9      10   Sakhi  Accountant  23-Mar-12  14-Mar-91    30.0  46000.0
# 10     11  Soniya  Accountant  24-Mar-14  24-Mar-91    30.0  47000.0

# %%
df[['empno','salary']]
# Out:
#     empno   salary
# 0       1      NaN
# 1       2  10000.0
# 2       3  50000.0
# 3       4      NaN
# 4       5  45000.0
# 5       6  45000.0
# 6       7  52000.0
# 7       8  56000.0
# 8       9  21000.0
# 9      10  46000.0
# 10     11  47000.0
# 11      1      NaN

# %%
df[8:20]
# Out:
#     empno   ename         job        DOJ        DOB  deptid   salary
# 8       9   Sayee      Cleark  16-Mar-12  22-Aug-98     NaN  21000.0
# 9      10   Sakhi  Accountant  23-Mar-12  14-Mar-91    30.0  46000.0
# 10     11  Soniya  Accountant  24-Mar-14  24-Mar-91    30.0  47000.0
# 11      1    Anil       Clerk        NaN        NaN     NaN      NaN

# %%
## getting rid of the null values in the dataset
df.dropna()
# Out:
#     empno   ename         job        DOJ        DOB  deptid   salary
# 2       3  Mathew     Manager  16-Mar-12  16-Mar-92    20.0  50000.0
# 4       5   Vimal  Accountant  18-Mar-17  18-Mar-91    20.0  45000.0
# 5       6   Kamal  Accountant  19-Nov-13  18-Mar-91    20.0  45000.0
# 6       7   Nanda     Manager  20-Mar-12  20-Jan-97    20.0  52000.0
# 7       8  Khushi     Manager  21-Mar-12  21-Jun-94    20.0  56000.0
# 9      10   Sakhi  Accountant  23-Mar-12  14-Mar-91    30.0  46000.0
# 10     11  Soniya  Accountant  24-Mar-14  24-Mar-91    30.0  47000.0

# %%
df.dropna(how='all')
# Out:
#     empno       ename         job        DOJ        DOB  deptid   salary
# 0       1        Anil       Clerk        NaN        NaN     NaN      NaN
# 1       2  Balkrushna         NaN  15-Jul-17  16-Mar-12    10.0  10000.0
# 2       3      Mathew     Manager  16-Mar-12  16-Mar-92    20.0  50000.0
# 3       4       Suhas     Manager  16-Mar-12  17-Mar-91    20.0      NaN
# 4       5       Vimal  Accountant  18-Mar-17  18-Mar-91    20.0  45000.0
# 5       6       Kamal  Accountant  19-Nov-13  18-Mar-91    20.0  45000.0
# 6       7       Nanda     Manager  20-Mar-12  20-Jan-97    20.0  52000.0
# 7       8      Khushi     Manager  21-Mar-12  21-Jun-94    20.0  56000.0
# 8       9       Sayee      Cleark  16-Mar-12  22-Aug-98     NaN  21000.0
# 9      10       Sakhi  Accountant  23-Mar-12  14-Mar-91    30.0  46000.0
# 10     11      Soniya  Accountant  24-Mar-14  24-Mar-91    30.0  47000.0
# 11      1        Anil       Clerk        NaN        NaN     NaN      NaN

# %%
df.dropna(axis=1,how='all')
# Out:
#     empno       ename         job        DOJ        DOB  deptid   salary
# 0       1        Anil       Clerk        NaN        NaN     NaN      NaN
# 1       2  Balkrushna         NaN  15-Jul-17  16-Mar-12    10.0  10000.0
# 2       3      Mathew     Manager  16-Mar-12  16-Mar-92    20.0  50000.0
# 3       4       Suhas     Manager  16-Mar-12  17-Mar-91    20.0      NaN
# 4       5       Vimal  Accountant  18-Mar-17  18-Mar-91    20.0  45000.0
# 5       6       Kamal  Accountant  19-Nov-13  18-Mar-91    20.0  45000.0
# 6       7       Nanda     Manager  20-Mar-12  20-Jan-97    20.0  52000.0
# 7       8      Khushi     Manager  21-Mar-12  21-Jun-94    20.0  56000.0
# 8       9       Sayee      Cleark  16-Mar-12  22-Aug-98     NaN  21000.0
# 9      10       Sakhi  Accountant  23-Mar-12  14-Mar-91    30.0  46000.0
# 10     11      Soniya  Accountant  24-Mar-14  24-Mar-91    30.0  47000.0
# 11      1        Anil       Clerk        NaN        NaN     NaN      NaN

# %%
df.dropna(thresh=6)
# Out:
#     empno       ename         job        DOJ        DOB  deptid   salary
# 1       2  Balkrushna         NaN  15-Jul-17  16-Mar-12    10.0  10000.0
# 2       3      Mathew     Manager  16-Mar-12  16-Mar-92    20.0  50000.0
# 3       4       Suhas     Manager  16-Mar-12  17-Mar-91    20.0      NaN
# 4       5       Vimal  Accountant  18-Mar-17  18-Mar-91    20.0  45000.0
# 5       6       Kamal  Accountant  19-Nov-13  18-Mar-91    20.0  45000.0
# 6       7       Nanda     Manager  20-Mar-12  20-Jan-97    20.0  52000.0
# 7       8      Khushi     Manager  21-Mar-12  21-Jun-94    20.0  56000.0
# 8       9       Sayee      Cleark  16-Mar-12  22-Aug-98     NaN  21000.0
# 9      10       Sakhi  Accountant  23-Mar-12  14-Mar-91    30.0  46000.0
# 10     11      Soniya  Accountant  24-Mar-14  24-Mar-91    30.0  47000.0

# %%
## fillna() fills the given value in place of null values 
df.fillna('xyz')
# Out:
#     empno       ename         job        DOJ        DOB deptid salary
# 0       1        Anil       Clerk        xyz        xyz    xyz    xyz
# 1       2  Balkrushna         xyz  15-Jul-17  16-Mar-12     10  10000
# 2       3      Mathew     Manager  16-Mar-12  16-Mar-92     20  50000
# 3       4       Suhas     Manager  16-Mar-12  17-Mar-91     20    xyz
# 4       5       Vimal  Accountant  18-Mar-17  18-Mar-91     20  45000
# 5       6       Kamal  Accountant  19-Nov-13  18-Mar-91     20  45000
# 6       7       Nanda     Manager  20-Mar-12  20-Jan-97     20  52000
# 7       8      Khushi     Manager  21-Mar-12  21-Jun-94     20  56000
# 8       9       Sayee      Cleark  16-Mar-12  22-Aug-98    xyz  21000
# 9      10       Sakhi  Accountant  23-Mar-12  14-Mar-91     30  46000
# 10     11      Soniya  Accountant  24-Mar-14  24-Mar-91     30  47000
# 11      1        Anil       Clerk        xyz        xyz    xyz    xyz

# %%
df.isnull()
# Out:
#     empno  ename    job    DOJ    DOB  deptid  salary
# 0   False  False  False   True   True    True    True
# 1   False  False   True  False  False   False   False
# 2   False  False  False  False  False   False   False
# 3   False  False  False  False  False   False    True
# 4   False  False  False  False  False   False   False
# 5   False  False  False  False  False   False   False
# 6   False  False  False  False  False   False   False
# 7   False  False  False  False  False   False   False
# 8   False  False  False  False  False    True   False
# 9   False  False  False  False  False   False   False
# 10  False  False  False  False  False   False   False
# 11  False  False  False   True   True    True    True

# %%
df.notnull()
# Out:
#     empno  ename    job    DOJ    DOB  deptid  salary
# 0    True   True   True  False  False   False   False
# 1    True   True  False   True   True    True    True
# 2    True   True   True   True   True    True    True
# 3    True   True   True   True   True    True   False
# 4    True   True   True   True   True    True    True
# 5    True   True   True   True   True    True    True
# 6    True   True   True   True   True    True    True
# 7    True   True   True   True   True    True    True
# 8    True   True   True   True   True   False    True
# 9    True   True   True   True   True    True    True
# 10   True   True   True   True   True    True    True
# 11   True   True   True  False  False   False   False

# %%
df.dropna(axis=0,how='any')
# Out:
#     empno   ename         job        DOJ        DOB  deptid   salary
# 2       3  Mathew     Manager  16-Mar-12  16-Mar-92    20.0  50000.0
# 4       5   Vimal  Accountant  18-Mar-17  18-Mar-91    20.0  45000.0
# 5       6   Kamal  Accountant  19-Nov-13  18-Mar-91    20.0  45000.0
# 6       7   Nanda     Manager  20-Mar-12  20-Jan-97    20.0  52000.0
# 7       8  Khushi     Manager  21-Mar-12  21-Jun-94    20.0  56000.0
# 9      10   Sakhi  Accountant  23-Mar-12  14-Mar-91    30.0  46000.0
# 10     11  Soniya  Accountant  24-Mar-14  24-Mar-91    30.0  47000.0

# %%
## fill null values with the mean value of other values in the field
df.fillna({'salary':df['salary'].mean()})
# Out:
#     empno       ename         job        DOJ        DOB  deptid        salary
# 0       1        Anil       Clerk        NaN        NaN     NaN  41333.333333
# 1       2  Balkrushna         NaN  15-Jul-17  16-Mar-12    10.0  10000.000000
# 2       3      Mathew     Manager  16-Mar-12  16-Mar-92    20.0  50000.000000
# 3       4       Suhas     Manager  16-Mar-12  17-Mar-91    20.0  41333.333333
# 4       5       Vimal  Accountant  18-Mar-17  18-Mar-91    20.0  45000.000000
# 5       6       Kamal  Accountant  19-Nov-13  18-Mar-91    20.0  45000.000000
# 6       7       Nanda     Manager  20-Mar-12  20-Jan-97    20.0  52000.000000
# 7       8      Khushi     Manager  21-Mar-12  21-Jun-94    20.0  56000.000000
# 8       9       Sayee      Cleark  16-Mar-12  22-Aug-98     NaN  21000.000000
# 9      10       Sakhi  Accountant  23-Mar-12  14-Mar-91    30.0  46000.000000
# 10     11      Soniya  Accountant  24-Mar-14  24-Mar-91    30.0  47000.000000
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# dtype: bool

# %%
## drop_duplicate() removes duplicate values from the dataframe
df.drop_duplicates()
# Out:
#     empno       ename         job        DOJ        DOB  deptid   salary
# 0       1        Anil       Clerk        NaN        NaN     NaN      NaN
# 1       2  Balkrushna         NaN  15-Jul-17  16-Mar-12    10.0  10000.0
# 2       3      Mathew     Manager  16-Mar-12  16-Mar-92    20.0  50000.0
# 3       4       Suhas     Manager  16-Mar-12  17-Mar-91    20.0      NaN
# 4       5       Vimal  Accountant  18-Mar-17  18-Mar-91    20.0  45000.0
# 5       6       Kamal  Accountant  19-Nov-13  18-Mar-91    20.0  45000.0
# 6       7       Nanda     Manager  20-Mar-12  20-Jan-97    20.0  52000.0
# 7       8      Khushi     Manager  21-Mar-12  21-Jun-94    20.0  56000.0
# 8       9       Sayee      Cleark  16-Mar-12  22-Aug-98     NaN  21000.0
# 9      10       Sakhi  Accountant  23-Mar-12  14-Mar-91    30.0  46000.0
# 10     11      Soniya  Accountant  24-Mar-14  24-Mar-91    30.0  47000.0

# %%
## creating a dataframe
data=pd.DataFrame({'food':['bacon','pulled pork','bacon','pastrami','corned beef','bacon','pastrami','honey ham','nova lox'],'ounces':[4,3,12,6,7.5,8,3,5,6]})

# %%
data
# Out:
#           food  ounces
# 0        bacon     4.0
# 1  pulled pork     3.0
# 2        bacon    12.0
# 3     pastrami     6.0
# 4  corned beef     7.5
# 5        bacon     8.0
# 6     pastrami     3.0
# 7    honey ham     5.0
# 8     nova lox     6.0

# %%
meat_to_animal={'bacon': 'pig', 'pulled pork':'pig', 'pastrami':'cow', 'corned beef':'cow', 'honey ham':'pig','nova lox': 'salmon'}

# %%
lowercased=data['food'].str.lower()

# %%
 lowercased
# Out:
# 0          bacon
# 1    pulled pork
# 2          bacon
# 3       pastrami
# 4    corned beef
# 5          bacon
# 6       pastrami
# 7      honey ham
# 8       nova lox
# Name: food, dtype: object

# %%
## map() maps values from different dataframes having a common column. Here, the common column is "food".
data['animal']=lowercased.map(meat_to_animal)

# %%
data
# Out:
#           food  ounces  animal
# 0        bacon     4.0     pig
# 1  pulled pork     3.0     pig
# 2        bacon    12.0     pig
# 3     pastrami     6.0     cow
# 4  corned beef     7.5     cow
# 5        bacon     8.0     pig
# 6     pastrami     3.0     cow
# 7    honey ham     5.0     pig
# 8     nova lox     6.0  salmon

# %%
df
# Out:
#     empno       ename         job        DOJ        DOB  deptid   salary
# 0       1        Anil       Clerk        NaN        NaN     NaN      NaN
# 1       2  Balkrushna         NaN  15-Jul-17  16-Mar-12    10.0  10000.0
# 2       3      Mathew     Manager  16-Mar-12  16-Mar-92    20.0  50000.0
# 3       4       Suhas     Manager  16-Mar-12  17-Mar-91    20.0      NaN
# 4       5       Vimal  Accountant  18-Mar-17  18-Mar-91    20.0  45000.0
# 5       6       Kamal  Accountant  19-Nov-13  18-Mar-91    20.0  45000.0
# 6       7       Nanda     Manager  20-Mar-12  20-Jan-97    20.0  52000.0
# 7       8      Khushi     Manager  21-Mar-12  21-Jun-94    20.0  56000.0
# 8       9       Sayee      Cleark  16-Mar-12  22-Aug-98     NaN  21000.0
# 9      10       Sakhi  Accountant  23-Mar-12  14-Mar-91    30.0  46000.0
# 10     11      Soniya  Accountant  24-Mar-14  24-Mar-91    30.0  47000.0
# 11      1        Anil       Clerk        NaN        NaN     NaN      NaN

# %%
class_map={'Clerk':'Class 3','Manager':'Class 1','Accountant':'Class 2','Cleark':'Class 3'}

# %%
df['class']=df['job'].map(class_map)

# %%
df
# Out:
#     empno       ename         job        DOJ        DOB  deptid   salary  \
# 0       1        Anil       Clerk        NaN        NaN     NaN      NaN
# 1       2  Balkrushna         NaN  15-Jul-17  16-Mar-12    10.0  10000.0
# 2       3      Mathew     Manager  16-Mar-12  16-Mar-92    20.0  50000.0
# 3       4       Suhas     Manager  16-Mar-12  17-Mar-91    20.0      NaN
# 4       5       Vimal  Accountant  18-Mar-17  18-Mar-91    20.0  45000.0
# 5       6       Kamal  Accountant  19-Nov-13  18-Mar-91    20.0  45000.0
# 6       7       Nanda     Manager  20-Mar-12  20-Jan-97    20.0  52000.0
# 7       8      Khushi     Manager  21-Mar-12  21-Jun-94    20.0  56000.0
# 8       9       Sayee      Cleark  16-Mar-12  22-Aug-98     NaN  21000.0
# 9      10       Sakhi  Accountant  23-Mar-12  14-Mar-91    30.0  46000.0
# 10     11      Soniya  Accountant  24-Mar-14  24-Mar-91    30.0  47000.0
# 11      1        Anil       Clerk        NaN        NaN     NaN      NaN
#
#       class
# ...

# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as sns

# %%
slabs=['Low','Medium','High','Very High']

# %%
bins1=[5000,15000,25000,35000,60000]

# %%
df['slab']=pd.cut(df.salary,bins1,labels=slabs)

# %%
df
# Out:
#     empno       ename         job        DOJ        DOB  deptid   salary  \
# 0       1        Anil       Clerk        NaN        NaN     NaN      NaN
# 1       2  Balkrushna         NaN  15-Jul-17  16-Mar-12    10.0  10000.0
# 2       3      Mathew     Manager  16-Mar-12  16-Mar-92    20.0  50000.0
# 3       4       Suhas     Manager  16-Mar-12  17-Mar-91    20.0      NaN
# 4       5       Vimal  Accountant  18-Mar-17  18-Mar-91    20.0  45000.0
# 5       6       Kamal  Accountant  19-Nov-13  18-Mar-91    20.0  45000.0
# 6       7       Nanda     Manager  20-Mar-12  20-Jan-97    20.0  52000.0
# 7       8      Khushi     Manager  21-Mar-12  21-Jun-94    20.0  56000.0
# 8       9       Sayee      Cleark  16-Mar-12  22-Aug-98     NaN  21000.0
# 9      10       Sakhi  Accountant  23-Mar-12  14-Mar-91    30.0  46000.0
# 10     11      Soniya  Accountant  24-Mar-14  24-Mar-91    30.0  47000.0
# 11      1        Anil       Clerk        NaN        NaN     NaN      NaN
#
# ...

# %%
df=df.drop("slab",axis=1)

# %%
df
# Out:
#     empno       ename         job        DOJ        DOB  deptid   salary  \
# 0       1        Anil       Clerk        NaN        NaN     NaN      NaN
# 1       2  Balkrushna         NaN  15-Jul-17  16-Mar-12    10.0  10000.0
# 2       3      Mathew     Manager  16-Mar-12  16-Mar-92    20.0  50000.0
# 3       4       Suhas     Manager  16-Mar-12  17-Mar-91    20.0      NaN
# 4       5       Vimal  Accountant  18-Mar-17  18-Mar-91    20.0  45000.0
# 5       6       Kamal  Accountant  19-Nov-13  18-Mar-91    20.0  45000.0
# 6       7       Nanda     Manager  20-Mar-12  20-Jan-97    20.0  52000.0
# 7       8      Khushi     Manager  21-Mar-12  21-Jun-94    20.0  56000.0
# 8       9       Sayee      Cleark  16-Mar-12  22-Aug-98     NaN  21000.0
# 9      10       Sakhi  Accountant  23-Mar-12  14-Mar-91    30.0  46000.0
# 10     11      Soniya  Accountant  24-Mar-14  24-Mar-91    30.0  47000.0
# 11      1        Anil       Clerk        NaN        NaN     NaN      NaN
#
#       class
# ...

# %%
from sklearn import preprocessing

# %%
X_train=np.array([[1.,-1.,2.],...,[2.,0.,0.],...,[0.,1.,-1.]])

# %%
from sklearn.preprocessing import StandardScaler

# %%
data=[[0,0],[0,0],[1,1],[1,1]]

# %%
scaler=StandardScaler()

# %%
## scaling the data 
print(scaler.fit(data))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
print(scaler.mean_)
# Out:
# [0.5 0.5]

# %%
print(scaler.transform(data))
# Out:
# [[-1. -1.]
#  [-1. -1.]
#  [ 1.  1.]
#  [ 1.  1.]]

# %%
print(scaler.transform([[2,2]]))
# Out:
# [[3. 3.]]

# %%
## plotting a histogram
df.hist(column='salary',bins=7)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f42ccb6f978>]],
#       dtype=object)

# %%
## corr() gives the correlation in the columns of the dataframe 
df.corr()
# Out:
#            empno    deptid    salary
# empno   1.000000  0.864882  0.322819
# deptid  0.864882  1.000000  0.613446
# salary  0.322819  0.613446  1.000000

# %%
print(df.corr(method="pearson"))
# Out:
#            empno    deptid    salary
# empno   1.000000  0.864882  0.322819
# deptid  0.864882  1.000000  0.613446
# salary  0.322819  0.613446  1.000000

# %%
## heatmap for pearson correlation for the dataframe
sns.heatmap(df.corr(method="pearson"))

# %%
sns.heatmap(df.corr())
